# %%
import pandas as pd
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
ruta_customer = r"C:\Users\laura\OneDrive\Escritorio\customer-details.xlsx"
df_customer = pd.read_excel(ruta_customer, sheet_name=0, header=0, index_col=None)

# %%
df_customer.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  161770        1         0  2012-04-04                 29
# 1           1   85477        1         1  2012-12-30                  7
# 2           2  147233        1         1  2012-02-02                  5
# 3           3  121393        1         2  2012-12-21                 29
# 4           4   63164        1         2  2012-06-20                 20
#
#                                      ID
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079
# 1  e9d37224-cb6f-4942-98d7-46672963d097
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b
# 3  9991fafb-4447-451a-8be2-b0df6098d13e
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb

# %%
df_customer.shape
# Out:
# (20115, 7)

# %%
todas_las_hojas = pd.read_excel(ruta_customer, sheet_name=None)

# %%
df_customer = pd.concat(todas_las_hojas.values(), ignore_index=True)

# %%
print("Total de filas leidas:", df_customer.shape[0])
# Out:
# Total de filas leidas: 43170

# %%
df_customer.head()
# Out:
#    Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0           0  161770        1         0  2012-04-04                 29
# 1           1   85477        1         1  2012-12-30                  7
# 2           2  147233        1         1  2012-02-02                  5
# 3           3  121393        1         2  2012-12-21                 29
# 4           4   63164        1         2  2012-06-20                 20
#
#                                      ID
# 0  089b39d8-e4d0-461b-87d4-814d71e0e079
# 1  e9d37224-cb6f-4942-98d7-46672963d097
# 2  3f9f49b5-e410-4948-bf6e-f9244f04918b
# 3  9991fafb-4447-451a-8be2-b0df6098d13e
# 4  eca60b76-70b6-4077-80ba-bc52e8ebb0eb

# %%
df_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         43170 non-null  int64
#  1   Income             43170 non-null  int64
#  2   Kidhome            43170 non-null  int64
#  3   Teenhome           43170 non-null  int64
#  4   Dt_Customer        43170 non-null  datetime64[us]
#  5   NumWebVisitsMonth  43170 non-null  int64
#  6   ID                 43170 non-null  str
# dtypes: datetime64[us](1), int64(5), str(1)
# memory usage: 2.3 MB

# %%
import pandas as pd

if 'Unnamed: 0' in df_customer.columns:
    df_customer = df_customer.drop(columns=['Unnamed: 0'])

df_customer['Dt_Customer'] = pd.to_datetime(df_customer['Dt_Customer'], errors='coerce')

df_customer = df_customer.drop_duplicates(subset=['ID'])

df_customer['Total_Dependents'] = df_customer['Kidhome'] + df_customer['Teenhome']

df_customer['Has_Kids'] = (df_customer['Total_Dependents'] > 0).astype(int)

df_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Income             43170 non-null  int64
#  1   Kidhome            43170 non-null  int64
#  2   Teenhome           43170 non-null  int64
#  3   Dt_Customer        43170 non-null  datetime64[us]
#  4   NumWebVisitsMonth  43170 non-null  int64
#  5   ID                 43170 non-null  str
#  6   Total_Dependents   43170 non-null  int64
#  7   Has_Kids           43170 non-null  int64
# dtypes: datetime64[us](1), int64(6), str(1)
# memory usage: 2.6 MB

# %%
df_customer.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43170 entries, 0 to 43169
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         43170 non-null  int64
#  1   Income             43170 non-null  int64
#  2   Kidhome            43170 non-null  int64
#  3   Teenhome           43170 non-null  int64
#  4   Dt_Customer        43170 non-null  datetime64[us]
#  5   NumWebVisitsMonth  43170 non-null  int64
#  6   ID                 43170 non-null  str
# dtypes: datetime64[us](1), int64(5), str(1)
# memory usage: 2.3 MB

# %%
import pandas as pd

df_bank = pd.read_csv(r"C:\Users\laura\OneDrive\Escritorio\bank-additional.csv") 

df_merged = pd.merge(
    df_bank, 
    df_customer, 
    left_on='id_', 
    right_on='ID', 
    how='inner'
)

if 'ID' in df_merged.columns:
    df_merged = df_merged.drop(columns=['ID'])

df_merged.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0_x       43000 non-null  int64
#  1   age                37880 non-null  float64
#  2   job                42655 non-null  str
#  3   marital            42915 non-null  str
#  4   education          41193 non-null  str
#  5   default            34019 non-null  float64
#  6   housing            41974 non-null  float64
#  7   loan               41974 non-null  float64
#  8   contact            43000 non-null  str
#  9   duration           43000 non-null  int64
#  10  campaign           43000 non-null  int64
#  11  pdays              43000 non-null  int64
#  12  previous           43000 non-null  int64
#  13  poutcome           43000 non-null  str
#  14  emp.var.rate       43000 non-null  float64
#  15  cons.price.idx     42529 non-null  str
# ...
